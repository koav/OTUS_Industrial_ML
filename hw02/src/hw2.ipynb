# %%
import os
import numpy as np
import pandas as pd
import pyarrow as pa
import pyarrow.parquet as pq

# %%
train_path = os.listdir('../dataset/train')
test_path = os.listdir('../dataset/test')

print(train_path)
print(test_path)
# Out:
# ['date=2018-02-01', 'date=2018-02-02', 'date=2018-02-03', 'date=2018-02-04', 'date=2018-02-05', 'date=2018-02-06', 'date=2018-02-07', 'date=2018-02-08', 'date=2018-02-09', 'date=2018-02-10', 'date=2018-02-12', 'date=2018-02-13', 'date=2018-02-14', 'date=2018-02-15', 'date=2018-02-16', 'date=2018-02-17', 'date=2018-02-18', 'date=2018-02-19', 'date=2018-02-20', 'date=2018-02-21', 'date=2018-02-22', 'date=2018-02-23', 'date=2018-02-24', 'date=2018-02-25', 'date=2018-02-26', 'date=2018-02-27', 'date=2018-02-28', 'date=2018-03-01', 'date=2018-03-02', 'date=2018-03-03', 'date=2018-03-04', 'date=2018-03-05', 'date=2018-03-06', 'date=2018-03-07', 'date=2018-03-08', 'date=2018-03-09', 'date=2018-03-10', 'date=2018-03-11', 'date=2018-03-12', 'date=2018-03-13', 'date=2018-03-14', 'date=2018-03-15', 'date=2018-03-16', 'date=2018-03-17', 'date=2018-03-18', 'date=2018-03-19', 'date=2018-03-20', 'date=2018-03-21', '_common_metadata', '_metadata', '_SUCCESS']
# <class 'list'>

# %%
data = pq.read_table('../dataset/train/date=2018-02-07').to_pandas()
data.head(10)
# Out:
#    instanceId_userId instanceId_objectType  instanceId_objectId  audit_pos  \
# 0                173                 Photo              3187174          8
# 1                392                  Post             25653289          2
# 2                482                  Post             28597489          0
# 3                677                  Post             24734385          2
# 4                803                  Post             16701484         10
# 5               1085                  Post             16066491         33
# 6               1085                  Post             16707808          3
# 7               1325                  Post             26751805          7
# 8               1418                  Post             15652104          2
# 9               1730                  Post             30453811          6
#
#   audit_clientType  audit_timestamp  audit_timePassed  audit_resourceType  \
# 0              MOB    1518027320610           2477188                   3
# 1              API    1517999642698          14061930                   8
# 2              API    1518017550599         158887656                  14
# 3              API    1518024150740          30873010                   8
# 4              WEB    1518033115927            185743                   8
# 5              API    1518009042767            623953                   8
# 6              API    1518009761702            719045                   8
# 7              MOB    1518016444325            643362                   8
# 8              API    1518018077467          78597021                   8
# 9              API    1518030671680           1007830                   8
#
#    metadata_ownerId   metadata_ownerType  ...  \
# 0             80461           GROUP_OPEN  ...
# 1              2398  GROUP_OPEN_OFFICIAL  ...
# 2             33222  GROUP_OPEN_OFFICIAL  ...
# 3             65142  GROUP_OPEN_OFFICIAL  ...
# 4              7473  GROUP_OPEN_OFFICIAL  ...
# 5             13015  GROUP_OPEN_OFFICIAL  ...
# 6              7473  GROUP_OPEN_OFFICIAL  ...
# 7             80709  GROUP_OPEN_OFFICIAL  ...
# 8             68049  GROUP_OPEN_OFFICIAL  ...
# 9             30935  GROUP_OPEN_OFFICIAL  ...
#
#    auditweights_userOwner_PHOTO_VIEW  auditweights_userOwner_TEXT  \
# 0                                NaN                          NaN
# 1                                NaN                          NaN
# 2                                NaN                          NaN
# 3                                NaN                          NaN
# 4                                NaN                          NaN
# 5                                NaN                     0.999089
# 6                                NaN                          NaN
# 7                                NaN                          NaN
# 8                                NaN                          NaN
# 9                                NaN                          NaN
#
#    auditweights_userOwner_UNKNOWN  auditweights_userOwner_USER_FEED_REMOVE  \
# 0                             NaN                                      NaN
# 1                             NaN                                      NaN
# 2                             NaN                                      NaN
# 3                             NaN                                      NaN
# 4                             NaN                                      NaN
# 5                             NaN                                      NaN
# 6                             NaN                                      NaN
# 7                             NaN                                      NaN
# 8                             NaN                                      NaN
# 9                             NaN                                      NaN
#
#    auditweights_userOwner_USER_PROFILE_VIEW  auditweights_userOwner_VIDEO  \
# 0                                       NaN                           NaN
# 1                                       NaN                           NaN
# 2                                       NaN                           NaN
# 3                                       NaN                           NaN
# 4                                       NaN                           NaN
# 5                                       NaN                           NaN
# 6                                       NaN                           NaN
# 7                                       NaN                           NaN
# 8                                       NaN                           NaN
# 9                                       NaN                           NaN
#
#    auditweights_x_ActorsRelations  auditweights_svd  \
# 0                             NaN          0.476469
# 1                             NaN          0.705798
# 2                           512.0          0.864366
# 3                             NaN          0.705589
# 4                             NaN          0.885362
# 5                             NaN          0.771723
# 6                             NaN          0.861918
# 7                         16384.0          0.662312
# 8                             NaN          0.663812
# 9                             NaN          0.945954
#
#                                              ImageId  \
# 0                                               None
# 1                 [aa201cf14b5a63a9e127ad1e5332e3fa]
# 2                                               None
# 3                 [6c0c1b7d30609dae56c769d7cfc34328]
# 4                 [16046b50cfe254602c6e28980ea3d351]
# 5                 [72bfd952a933e5e9523fa07242a7e095]
# 6                 [5ee45ab3bf9582149b5f90d32bb22294]
# 7  [65947835aec9293639a7a4b78b3eed53, 1177aecca38...
# 8                 [4ddf657df70b115e329ee2cfabc51664]
# 9                 [a871ded97834db2393f40800f7354d07]
#
#   auditweights_likersSvd_hyper
# 0                          NaN
# 1                          NaN
# 2                     0.533798
# 3                     0.904450
# 4                          NaN
# 5                          NaN
# 6                          NaN
# 7                     0.651852
# 8                     0.838941
# 9                          NaN
#
# [10 rows x 106 columns]
